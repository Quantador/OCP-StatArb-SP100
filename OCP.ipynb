# %%
# %load_ext autoreload
# %autoreload 2

from src.preprocessing import *
import src.ocp as ocp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#1) Get selected tickers
tickers = get_selected_tickers()

# 2) Load per-ticker returns
frames = load_selected_ticker_frames()
# Out:
# 2025-12-22 15:42:07,920 | INFO | Found 90 selected tickers.
# 2025-12-22 15:42:08,839 | INFO | Loaded 90 selected ticker frames into memory.

# %%
DATA_DIR = Path("data/selected/SP100/bbo")
TICKERS = tickers

daily_matrices = ocp.build_daily_return_matrices(
    data_dir=DATA_DIR,
    ticker_list=TICKERS,
    return_col="mid_price_return"
)

print(f"Built {len(daily_matrices)} daily return matrices.")

daily_pairs = ocp.build_daily_pairs(daily_matrices)
# Out:
# Built 573 daily return matrices.

# %%
first_n_days = 10

daily_top = ocp.ocp_run_all_days_fast(
    daily_matrices=daily_matrices,
    daily_pairs=daily_pairs,
    top_k=10,
    keep_top_pairs=None,
    max_lag=30,       
    band=10,          
    first_n_days=first_n_days
)

daily_top.to_parquet(f"data/top_pairs/daily_top_pairs_{first_n_days}.parquet", index=False)
# Out:
# 100%|██████████| 10/10 [00:06<00:00,  1.62it/s]

# %%
daily_top = pd.read_parquet(f"data/top_pairs/daily_top_pairs_{first_n_days}.parquet")

daily_top
# Out:
#          date   leader  follower     l_hat   sigma_l      cost
# 0  2015-01-02    MRK.N     LOW.N  1.050847  1.850778  0.126516
# 1  2015-01-02    MMM.N      GD.N -1.050328  1.936544  0.099482
# 2  2015-01-02    BLK.N  CMCSA.OQ -1.039419  1.976129  0.140185
# 3  2015-01-02    ALL.N      SO.N  1.168831  2.040091  0.134003
# 4  2015-01-02  BIIB.OQ     LOW.N  1.076923  2.061504  0.178299
# 5  2015-01-02    WFC.N      GM.N -1.337553  2.079634  0.143226
# 6  2015-01-02  FOXA.OQ   PCLN.OQ -1.056842  2.118324  0.113698
# 7  2015-01-02    CAT.N      KO.N -1.020877  2.130302  0.123493
# 8  2015-01-02    BMY.N     COF.N  1.217119  2.135015  0.130061
# 9  2015-01-02    DUK.N   PCLN.OQ  1.000000  2.169767  0.141735
