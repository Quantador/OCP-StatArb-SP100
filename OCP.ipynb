# %%
from src.preprocessing import *
from src.ocp import *

# %%
#1) Get selected tickers
tickers = get_selected_tickers()

# 2) Load per-ticker returns
frames = load_selected_ticker_frames()

# 3) Build wide returns panel
panel = build_returns_panel(frames)

# 4) Generate pairs
pairs = generate_ticker_pairs(tickers)
# Out:
# 2025-12-14 16:21:45,190 | INFO | Found 90 selected tickers.
# 2025-12-14 16:21:47,064 | INFO | Loaded 90 selected ticker frames into memory.
# 2025-12-14 16:21:51,551 | INFO | Returns panel built: 222897 rows x 90 tickers (+1 timestamp column).
# 2025-12-14 16:21:51,551 | WARNING | Returns panel contains 211616 null entries. Consider dropping or imputing rows with nulls before OCP.
# 2025-12-14 16:21:51,729 | INFO | Generated 4005 ticker pairs from 90 tickers.

# %%
# Example timestamps (replace with your actual boundaries)
start_ts = panel.get_column("timestamp")[0]
end_ts   = panel.get_column("timestamp")[391]  # formation length example

arrays = extract_window_arrays(panel, tickers, start_ts, end_ts)
top_pairs = run_ocp_on_pairs(arrays, pairs, top_k=10, band=30)  # band helps speed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 start_ts = panel.get_column("timestamp")[0]
#       3 end_ts   = panel.get_column("timestamp")[391]  # formation length example
# ----> 5 arrays = extract_window_arrays(panel, tickers, start_ts, end_ts)
#       6 top_pairs = run_ocp_on_pairs(arrays, pairs, top_k=10, band=30)  # band helps speed
#
# NameError: name 'extract_window_arrays' is not defined
