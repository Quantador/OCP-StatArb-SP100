# %%
# %load_ext autoreload
# %autoreload 2



from src.preprocessing import *
from src.ocp import *

# %%
#1) Get selected tickers
tickers = get_selected_tickers()

# 2) Load per-ticker returns
frames = load_selected_ticker_frames()

# 3) Build wide returns panel
panel = build_returns_panel(frames)

# 4) Generate pairs
pairs = generate_ticker_pairs(tickers)
# Out:
# 2025-12-22 13:27:42,177 | INFO | Found 90 selected tickers.
# 2025-12-22 13:27:47,250 | INFO | Loaded 90 selected ticker frames into memory.
# 2025-12-22 13:27:51,214 | INFO | Returns panel built: 222897 rows x 90 tickers (+1 timestamp column).
# 2025-12-22 13:27:51,220 | WARNING | Returns panel contains 211616 null entries. Consider dropping or imputing rows with nulls before OCP.

# %%
# Out:
# {'AAPL.OQ': (219785, 2), 'ABT.N': (219785, 2), 'ACN.N': (219785, 2), 'AIG.N': (219785, 2), 'ALL.N': (219785, 2), 'AMGN.OQ': (219785, 2), 'AXP.N': (222897, 2), 'BA.N': (222897, 2), 'BAC.N': (219785, 2), 'BIIB.OQ': (219785, 2), 'BK.N': (219785, 2), 'BLK.N': (219785, 2), 'BMY.N': (219785, 2), 'C.N': (219785, 2), 'CAT.N': (222897, 2), 'CELG.OQ': (219785, 2), 'CL.N': (219785, 2), 'CMCSA.OQ': (219785, 2), 'COF.N': (219785, 2), 'COP.N': (219785, 2), 'COST.OQ': (219785, 2), 'CSCO.OQ': (219785, 2), 'CVS.N': (219785, 2), 'CVX.N': (222897, 2), 'DD.N': (219785, 2), 'DHR.N': (219785, 2), 'DIS.N': (222897, 2), 'DOW.N': (222897, 2), 'DUK.N': (219785, 2), 'EMR.N': (219785, 2), 'EXC.N': (219785, 2), 'F.N': (219785, 2), 'FDX.N': (219785, 2), 'FOXA.OQ': (219785, 2), 'GD.N': (219785, 2), 'GE.N': (219785, 2), 'GILD.OQ': (219785, 2), 'GM.N': (219785, 2), 'GOOG.OQ': (219785, 2), 'GOOGL.OQ': (219785, 2), 'GS.N': (222897, 2), 'HAL.N': (219785, 2), 'HD.N': (222897, 2), 'HON.N': (222897, 2), 'IBM.N': (222897, 2), 'INTC.OQ': (219785, 2), 'JNJ.N': (222897, 2), 'JPM.N': (222897, 2), 'KMI.N': (219785, 2), 'KO.N': (222897, 2), 'LLY.N': (219785, 2), 'LMT.N': (219785, 2), 'LOW.N': (219785, 2), 'MA.N': (219785, 2), 'MCD.N': (222897, 2), 'MDLZ.OQ': (219785, 2), 'MDT.N': (219785, 2), 'MET.N': (219785, 2), 'MMM.N': (222897, 2), 'MO.N': (219785, 2), 'MON.N': (219785, 2), 'MRK.N': (222897, 2), 'MS.N': (219785, 2), 'MSFT.OQ': (219785, 2), 'NEE.N': (219785, 2), 'NKE.N': (222897, 2), 'OXY.N': (219785, 2), 'PCLN.OQ': (219785, 2), 'PEP.N': (219785, 2), 'PFE.N': (219785, 2), 'PG.N': (222897, 2), 'PM.N': (219785, 2), 'QCOM.OQ': (219785, 2), 'RTN.N': (219785, 2), 'SBUX.OQ': (219785, 2), 'SLB.N': (219785, 2), 'SO.N': (219785, 2), 'SPG.N': (219785, 2), 'T.N': (219785, 2), 'TGT.N': (219785, 2), 'TWX.N': (219785, 2), 'UNH.N': (222897, 2), 'UNP.N': (219785, 2), 'UPS.N': (219785, 2), 'USB.N': (219785, 2), 'UTX.N': (219785, 2), 'V.N': (222897, 2), 'VZ.N': (222897, 2), 'WFC.N': (219785, 2), 'WMT.N': (222897, 2)}
# {'AAPL.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 18439            │
# └───────────┴──────────────────┘, 'ABT.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 78838            │
# └───────────┴──────────────────┘, 'ACN.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 40593            │
# └───────────┴──────────────────┘, 'AIG.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 64706            │
# └───────────┴──────────────────┘, 'ALL.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 60353            │
# └───────────┴──────────────────┘, 'AMGN.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 6116             │
# └───────────┴──────────────────┘, 'AXP.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 54915            │
# └───────────┴──────────────────┘, 'BA.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 35338            │
# └───────────┴──────────────────┘, 'BAC.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 124884           │
# └───────────┴──────────────────┘, 'BIIB.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 5016             │
# └───────────┴──────────────────┘, 'BK.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 80093            │
# └───────────┴──────────────────┘, 'BLK.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 35915            │
# └───────────┴──────────────────┘, 'BMY.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 52559            │
# └───────────┴──────────────────┘, 'C.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 63364            │
# └───────────┴──────────────────┘, 'CAT.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 42647            │
# └───────────┴──────────────────┘, 'CELG.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 7287             │
# └───────────┴──────────────────┘, 'CL.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 63502            │
# └───────────┴──────────────────┘, 'CMCSA.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 45086            │
# └───────────┴──────────────────┘, 'COF.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 44263            │
# └───────────┴──────────────────┘, 'COP.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 50648            │
# └───────────┴──────────────────┘, 'COST.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 10840            │
# └───────────┴──────────────────┘, 'CSCO.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 90995            │
# └───────────┴──────────────────┘, 'CVS.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 44241            │
# └───────────┴──────────────────┘, 'CVX.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 38567            │
# └───────────┴──────────────────┘, 'DD.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 49421            │
# └───────────┴──────────────────┘, 'DHR.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 51079            │
# └───────────┴──────────────────┘, 'DIS.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 47010            │
# └───────────┴──────────────────┘, 'DOW.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 65602            │
# └───────────┴──────────────────┘, 'DUK.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 47785            │
# └───────────┴──────────────────┘, 'EMR.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 61760            │
# └───────────┴──────────────────┘, 'EXC.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 84798            │
# └───────────┴──────────────────┘, 'F.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 154731           │
# └───────────┴──────────────────┘, 'FDX.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 33979            │
# └───────────┴──────────────────┘, 'FOXA.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 82026            │
# └───────────┴──────────────────┘, 'GD.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 36448            │
# └───────────┴──────────────────┘, 'GE.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 118850           │
# └───────────┴──────────────────┘, 'GILD.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 16181            │
# └───────────┴──────────────────┘, 'GM.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 89894            │
# └───────────┴──────────────────┘, 'GOOG.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 3513             │
# └───────────┴──────────────────┘, 'GOOGL.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 3699             │
# └───────────┴──────────────────┘, 'GS.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 32269            │
# └───────────┴──────────────────┘, 'HAL.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 55727            │
# └───────────┴──────────────────┘, 'HD.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 37682            │
# └───────────┴──────────────────┘, 'HON.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 40774            │
# └───────────┴──────────────────┘, 'IBM.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 34527            │
# └───────────┴──────────────────┘, 'INTC.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 74365            │
# └───────────┴──────────────────┘, 'JNJ.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 49804            │
# └───────────┴──────────────────┘, 'JPM.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 58465            │
# └───────────┴──────────────────┘, 'KMI.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 90286            │
# └───────────┴──────────────────┘, 'KO.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 103486           │
# └───────────┴──────────────────┘, 'LLY.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 44585            │
# └───────────┴──────────────────┘, 'LMT.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 34052            │
# └───────────┴──────────────────┘, 'LOW.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 48851            │
# └───────────┴──────────────────┘, 'MA.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 42640            │
# └───────────┴──────────────────┘, 'MCD.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 43490            │
# └───────────┴──────────────────┘, 'MDLZ.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 65724            │
# └───────────┴──────────────────┘, 'MDT.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 52428            │
# └───────────┴──────────────────┘, 'MET.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 60950            │
# └───────────┴──────────────────┘, 'MMM.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 35762            │
# └───────────┴──────────────────┘, 'MO.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 68715            │
# └───────────┴──────────────────┘, 'MON.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 44033            │
# └───────────┴──────────────────┘, 'MRK.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 66607            │
# └───────────┴──────────────────┘, 'MS.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 77099            │
# └───────────┴──────────────────┘, 'MSFT.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 48780            │
# └───────────┴──────────────────┘, 'NEE.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 37713            │
# └───────────┴──────────────────┘, 'NKE.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 56282            │
# └───────────┴──────────────────┘, 'OXY.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 41321            │
# └───────────┴──────────────────┘, 'PCLN.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 15297            │
# └───────────┴──────────────────┘, 'PEP.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 50712            │
# └───────────┴──────────────────┘, 'PFE.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 98862            │
# └───────────┴──────────────────┘, 'PG.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 60556            │
# └───────────┴──────────────────┘, 'PM.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 48447            │
# └───────────┴──────────────────┘, 'QCOM.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 40740            │
# └───────────┴──────────────────┘, 'RTN.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 37482            │
# └───────────┴──────────────────┘, 'SBUX.OQ': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 43127            │
# └───────────┴──────────────────┘, 'SLB.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 41500            │
# └───────────┴──────────────────┘, 'SO.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 77385            │
# └───────────┴──────────────────┘, 'SPG.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 34471            │
# └───────────┴──────────────────┘, 'T.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 105158           │
# └───────────┴──────────────────┘, 'TGT.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 49251            │
# └───────────┴──────────────────┘, 'TWX.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 46392            │
# └───────────┴──────────────────┘, 'UNH.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 35517            │
# └───────────┴──────────────────┘, 'UNP.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 38346            │
# └───────────┴──────────────────┘, 'UPS.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 43216            │
# └───────────┴──────────────────┘, 'USB.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 81509            │
# └───────────┴──────────────────┘, 'UTX.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 41373            │
# └───────────┴──────────────────┘, 'V.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 51425            │
# └───────────┴──────────────────┘, 'VZ.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 86133            │
# └───────────┴──────────────────┘, 'WFC.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 72518            │
# └───────────┴──────────────────┘, 'WMT.N': shape: (1, 2)
# ┌───────────┬──────────────────┐
# │ timestamp ┆ mid_price_return │
# │ ---       ┆ ---              │
# │ u32       ┆ u32              │
# ╞═══════════╪══════════════════╡
# │ 0         ┆ 65961            │
# └───────────┴──────────────────┘}

# %%
results_df = run_daily_ocp_pipeline(
    panel=panel,
    tickers=tickers,
    band=30,
    max_pairs_prefilter=500,
    top_k=10,
    checkpoint_path="checkpoints/ocp_daily.parquet",
    resume=True,
)

full_df = load_full_checkpoint("checkpoints/ocp_daily.parquet")
# Out:
# 2025-12-14 19:12:07,942 | INFO | [2015-01-02] formation window: rows 389->389 (dropped 0), tickers 90->90
# 2025-12-14 19:12:07,952 | INFO | [2015-01-02] prefilter pairs: keeping 500 pairs by |corr|
# 2025-12-14 19:13:53,274 | INFO | [2015-01-02] checkpoint saved: 10 rows -> checkpoints/ocp_daily.parquet
# 2025-12-14 19:13:53,282 | INFO | [2015-01-05] formation window: rows 389->389 (dropped 0), tickers 90->90
# 2025-12-14 19:13:53,293 | INFO | [2015-01-05] prefilter pairs: keeping 500 pairs by |corr|
# 2025-12-14 19:15:47,443 | INFO | [2015-01-05] checkpoint saved: 10 rows -> checkpoints/ocp_daily.parquet
# 2025-12-14 19:15:47,452 | INFO | [2015-01-06] formation window: rows 389->389 (dropped 0), tickers 90->90
# 2025-12-14 19:15:47,461 | INFO | [2015-01-06] prefilter pairs: keeping 500 pairs by |corr|
# 2025-12-14 19:17:32,781 | INFO | [2015-01-06] checkpoint saved: 10 rows -> checkpoints/ocp_daily.parquet
# 2025-12-14 19:17:32,792 | INFO | [2015-01-07] formation window: rows 389->389 (dropped 0), tickers 90->90
# 2025-12-14 19:17:32,807 | INFO | [2015-01-07] prefilter pairs: keeping 500 pairs by |corr|
# 2025-12-14 19:19:13,245 | INFO | [2015-01-07] checkpoint saved: 10 rows -> checkpoints/ocp_daily.parquet
# 2025-12-14 19:19:13,256 | INFO | [2015-01-08] formation window: rows 389->389 (dropped 0), tickers 90->90
# 2025-12-14 19:19:13,265 | INFO | [2015-01-08] prefilter pairs: keeping 500 pairs by |corr|
